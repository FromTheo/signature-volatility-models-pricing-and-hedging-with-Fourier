# %%
from trajectories import * 
from fourier_sig import * 
from fourier import *
from quadratic_hedging_fourier import *
from utils import * 
import time

# %% [markdown]
# ## I. European options

# %%
x, kappa, theta, eta, rho = 0.05, 1.0, 0.25, 1.2, -0.6 
M = 4

N = 2500
n = 252
S0 = 1
M = 4
L = 32
bell = compute_l_OU(x, kappa, theta, eta, M, intercept=False)

# %% [markdown]
# ### I.1. $T=1$ month

# %%
T = 1/12
W, paths = generate_paths(N, n, T)
W_perp = generate_brownian_paths(N, n, T)
B = rho * W + np.sqrt(1 - rho**2) * W_perp

# %% [markdown]
# #### I.1.1. $K = 0.9$

# %%
K = 0.9

# %%
PNL_Fourier_1_09 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_1_09, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:12<00:00, 20.53it/s]

# %%
plot_PnL_distribution(PNL_Fourier_1_09, PNL_Sig_1_09, title=r"$T = 1 \text{ month},\; K = 0.9$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# #### I.1.2. $K = 1.0$

# %%
K = 1.0

# %%
PNL_Fourier_1_1 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_1_1, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:11<00:00, 22.39it/s]

# %%
plot_PnL_distribution(PNL_Fourier_1_1, PNL_Sig_1_1, title=r"$T = 1 \text{ month},\; K = 1.0$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# #### I.1.3. $K = 1.1$

# %%
K = 1.1

# %%
PNL_Fourier_1_11 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_1_11, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:10<00:00, 22.96it/s]

# %%
plot_PnL_distribution(PNL_Fourier_1_11, PNL_Sig_1_11, title=r"$T = 1 \text{ month},\; K = 1.1$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# ### I.2. $T = 6$ months

# %%
T = 0.5
W, paths = generate_paths(N, n, T)
W_perp = generate_brownian_paths(N, n, T)
B = rho * W + np.sqrt(1 - rho**2) * W_perp

# %% [markdown]
# #### I.2.1. $K = 0.75$

# %%
K = 0.75

# %%
PNL_Fourier_6_075 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_6_075, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:11<00:00, 22.51it/s]

# %%
plot_PnL_distribution(PNL_Fourier_6_075, PNL_Sig_6_075, title=r"$T = 6 \text{ months},\; K = 0.75$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# #### I.2.2. $K = 1.0$

# %%
K = 1.0

# %%
PNL_Fourier_6_1 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_6_1, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:11<00:00, 21.26it/s]

# %%
plot_PnL_distribution(PNL_Fourier_6_1, PNL_Sig_6_1, title=r"$T = 6 \text{ months},\; K = 1.0$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# #### I.2.3. $K = 1.25$

# %%
K = 1.25

# %%
PNL_Fourier_6_125 = quadratic_hedging_PnL_europ_SteinStein(kappa, theta, eta, rho, S0, x, K, T, W, B, L, flag="put")

# %%
PNL_Sig_6_125, _, _ = quadratic_hedging_PnL_europ(x, bell, rho, S0, K, T, L, M, n, W, B, paths, flag="put")
# Out:
# ...
# Step 4. Computing bracket: 100%|██████████████| 252/252 [00:11<00:00, 21.61it/s]

# %%
plot_PnL_distribution(PNL_Fourier_6_125, PNL_Sig_6_125, title=r"$T = 6 \text{ months},\; K = 1.25$", BS=False)
# Out:
# Which model? :  $\text{SteinStein}$

# %% [markdown]
# ### I.3. Common figure

# %%
fig, ax = plt.subplots(2, 3, figsize=(7*3, 5*2))
ax = ax.flatten()
clip_q = 0.999
nbins=50

lo = np.quantile(np.concatenate([PNL_Fourier_1_09, PNL_Sig_1_09]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_1_09, PNL_Sig_1_09]), clip_q)
PNL_Fourier_1_09_  = np.clip(PNL_Fourier_1_09,  lo, hi)
PNL_Sig_1_09_ = np.clip(PNL_Sig_1_09, lo, hi)
xmin = min(PNL_Fourier_1_09_.min(), PNL_Sig_1_09_.min())
xmax = max(PNL_Fourier_1_09_.max(), PNL_Sig_1_09_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_1_09_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_1_09_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[0].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[0].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[0].set_title(r"$T = 1\text{ month},\: K = 0.9$", fontsize=14)

lo = np.quantile(np.concatenate([PNL_Fourier_1_1, PNL_Sig_1_1]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_1_1, PNL_Sig_1_1]), clip_q)
PNL_Fourier_1_1_  = np.clip(PNL_Fourier_1_1,  lo, hi)
PNL_Sig_1_1_ = np.clip(PNL_Sig_1_1, lo, hi)
xmin = min(PNL_Fourier_1_1_.min(), PNL_Sig_1_1_.min())
xmax = max(PNL_Fourier_1_1_.max(), PNL_Sig_1_1_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_1_1_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_1_1_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[1].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[1].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[1].set_title(r"$T = 1\text{ month},\: K = 1$", fontsize=14)

lo = np.quantile(np.concatenate([PNL_Fourier_1_11, PNL_Sig_1_11]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_1_11, PNL_Sig_1_11]), clip_q)
PNL_Fourier_1_11_  = np.clip(PNL_Fourier_1_11,  lo, hi)
PNL_Sig_1_11_ = np.clip(PNL_Sig_1_11, lo, hi)
xmin = min(PNL_Fourier_1_11_.min(), PNL_Sig_1_11_.min())
xmax = max(PNL_Fourier_1_11_.max(), PNL_Sig_1_11_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_1_11_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_1_11_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[2].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[2].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[2].set_title(r"$T = 1\text{ month},\: K = 1.1$", fontsize=14)

lo = np.quantile(np.concatenate([PNL_Fourier_6_075, PNL_Sig_6_075]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_6_075, PNL_Sig_6_075]), clip_q)
PNL_Fourier_6_075_  = np.clip(PNL_Fourier_6_075,  lo, hi)
PNL_Sig_6_075_ = np.clip(PNL_Sig_6_075, lo, hi)
xmin = min(PNL_Fourier_6_075_.min(), PNL_Sig_6_075_.min())
xmax = max(PNL_Fourier_6_075_.max(), PNL_Sig_6_075_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_6_075_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_6_075_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[3].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[3].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[3].set_title(r"$T = 6\text{ months},\: K = 0.75$", fontsize=14)

lo = np.quantile(np.concatenate([PNL_Fourier_6_1, PNL_Sig_6_1]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_6_1, PNL_Sig_6_1]), clip_q)
PNL_Fourier_6_1_  = np.clip(PNL_Fourier_6_1,  lo, hi)
PNL_Sig_6_1_ = np.clip(PNL_Sig_6_1, lo, hi)
xmin = min(PNL_Fourier_6_1_.min(), PNL_Sig_6_1_.min())
xmax = max(PNL_Fourier_6_1_.max(), PNL_Sig_6_1_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_6_1_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_6_1_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[4].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[4].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[4].set_title(r"$T = 6\text{ months},\: K = 1$", fontsize=14)

lo = np.quantile(np.concatenate([PNL_Fourier_6_125, PNL_Sig_6_125]), 1-clip_q)
hi = np.quantile(np.concatenate([PNL_Fourier_6_125, PNL_Sig_6_125]), clip_q)
PNL_Fourier_6_125_  = np.clip(PNL_Fourier_6_125,  lo, hi)
PNL_Sig_6_125_ = np.clip(PNL_Sig_6_125, lo, hi)
xmin = min(PNL_Fourier_6_125_.min(), PNL_Sig_6_125_.min())
xmax = max(PNL_Fourier_6_125_.max(), PNL_Sig_6_125_.max())
bins = np.linspace(xmin, xmax, nbins + 1)
c_bs,  _ = np.histogram(PNL_Fourier_6_125_,  bins=bins)
c_sig, _ = np.histogram(PNL_Sig_6_125_, bins=bins)
p_bs  = 100.0 * c_bs  / max(c_bs.sum(), 1)
p_sig = 100.0 * c_sig / max(c_sig.sum(), 1)
centers = 0.5 * (bins[:-1] + bins[1:])
binw = (bins[1] - bins[0])
w = 0.42 * binw 
offset = 0.5 * w
ax[5].bar(centers - offset, p_bs,  width=w, label=r"$\text{SteinStein}$")
ax[5].bar(centers + offset, p_sig, width=w, label=r"$M=4$")
ax[5].set_title(r"$T = 6\text{ months},\: K = 1.25$", fontsize=14)

for i in range(6) : 
    ax[i].xaxis.set_major_formatter(lambda x, _: f"${x:g}$")
    ax[i].yaxis.set_major_formatter(lambda y, _: fr"${y:g}\%$")
    ax[i].tick_params(axis='both', labelsize=12) 
    ax[i].legend(loc="upper left", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## II. Asian options

# %%
y, kappa, theta, eta, alpha, rho = 0.25, 1, 0.25, 1.2, 0.6, -0.6
M = 4
bell = compute_l_mGBM(y, kappa, theta, eta, alpha, M) 

N = 2500
n = 252
S0 = 1
M = 4
L = 32

# %% [markdown]
# ### 1. $T = 1$ month

# %%
T = 1/12
W, paths = generate_paths(N, n, T)
W_perp = generate_brownian_paths(N, n, T)
B = rho * W + np.sqrt(1 - rho**2) * W_perp

# %% [markdown]
# #### 1.1 $K = 1$

# %%
K = 1

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2684.14it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (5.667374048429581e-05, 7.587637512251719e-05)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 1 \text{ month},\; K = 1$")

# %% [markdown]
# #### 1.2 $K = 0.95$

# %%
K = 0.95

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2684.87it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (3.0661920362230665e-05, 7.49051438507142e-05)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 1 \text{ month},\; K = 0.95$")

# %% [markdown]
# #### 1.3 $K = 1.05$

# %%
K = 1.05

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2649.97it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (1.8603914860003107e-05, 2.6569635653388303e-05)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 1 \text{ month},\; K = 1.05$")

# %% [markdown]
# ### 2. $T = 6$ months

# %%
T = 0.5
W, paths = generate_paths(N, n, T)
W_perp = generate_brownian_paths(N, n, T)
B = rho * W + np.sqrt(1 - rho**2) * W_perp

# %% [markdown]
# #### 2.1 $K = 1$

# %%
K = 1

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2700.55it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (0.0014851659493024484, 0.0026753035696562384)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 6 \text{ months},\; K = 1$")

# %% [markdown]
# #### 2.2 $K = 0.85$

# %%
K = 0.85

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2663.09it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (0.0009595039399878683, 0.0022659246457308354)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 6 \text{ months},\; K = 0.85$")

# %% [markdown]
# #### 2.3 $K = 1.15$

# %%
K = 1.15

# %%
PnL_Sig, PnL_BS = quadratic_hedging_PnL_asian_sig(y, bell, rho, S0, K, T, L, M, n, W, B, paths, sigma_BS=0.25, flag="put")
# Out:
# Simulating: 100%|█████████████████████████| 2500/2500 [00:00<00:00, 2593.51it/s]

# %%
np.mean(PnL_Sig**2), np.mean(PnL_BS**2)
# Out:
# (0.0009753565741534358, 0.0012429741392810255)

# %%
plot_PnL_distribution(PnL_BS, PnL_Sig, title=r"$T = 6 \text{ months},\; K = 1.15$")
